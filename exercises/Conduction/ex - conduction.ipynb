# %% [markdown]
# # Conduction
#
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
print("This is an example!")
# Out:
# This is an example!

# %% [markdown]
# ---
#
# [MOC](../ex%20-%2000%20moc.md) | [Home](../readme.md)
